# %%
import pandas as pd

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
flights = pd.read_csv(r"C:\Users\n460923\PY docs\test_scatter.csv")
flights
# Out:
#         a       b      c
# 0    0.51 -0.0019  211.3
# 1    0.00  0.0128  523.9
# 2    0.30  0.0105  378.8
# 3    0.55 -0.0026   81.5
# 4    0.68  0.0049  515.0
# ..    ...     ...    ...
# 184  0.85 -0.0008  212.1
# 185  0.98 -0.0040   35.6
# 186  0.81  0.0024  118.4
# 187  0.94 -0.0042   60.0
# 188  0.95 -0.0051   29.4
#
# [189 rows x 3 columns]

# %%
a_list = flights["a"].tolist()
b_list = flights["b"].tolist()
c_list = flights["c"].tolist()
print(a_list)
type(a_list)
# Out:
# [0.51, 0.0, 0.3, 0.55, 0.68, 0.45, 0.54, 0.48, 0.64, 0.37, 0.79, 0.55, 0.57, 0.67, 0.79, 0.86, 0.69, 0.76, 0.97, 0.63, 0.51, 0.57, 0.67, 0.75, 0.58, 0.78, 0.74, 0.45, 0.4, 0.65, 0.47, 0.83, 0.46, 0.72, 0.74, 0.62, 0.32, 0.85, 0.73, 0.7, 0.59, 0.98, 0.85, 0.69, 0.78, 0.91, 0.85, 0.73, 0.46, 0.63, 0.83, 0.66, 0.76, 0.89, 0.56, 0.58, 0.83, 0.58, 0.87, 0.57, 0.88, 0.81, 0.72, 0.59, 0.75, 0.87, 0.89, 0.59, 0.92, 1.0, 0.78, 0.83, 0.96, 0.82, 0.76, 0.75, 0.63, 0.78, 0.84, 0.72, 0.98, 0.74, 0.85, 0.52, 0.78, 0.81, 0.91, 0.88, 0.93, 0.85, 0.81, 0.84, 0.83, 0.78, 0.99, 0.81, 0.87, 0.92, 0.64, 1.0, 1.0, 1.0, 0.84, 1.0, 0.68, 0.76, 0.9, 0.84, 0.96, 1.0, 0.65, 0.65, 0.93, 0.98, 0.99, 0.9, 1.0, 0.9, 0.99, 0.96, 0.84, 0.97, 1.0, 0.98, 0.85, 0.83, 0.95, 0.93, 1.0, 0.96, 1.0, 0.65, 0.86, 0.82, 0.99, 0.93, 1.0, 0.83, 1.0, 0.88, 0.91, 1.0, 0.9, 1.0, 0.86, 0.88, 0.89, 0.88, 0.95, 0.98, 0.86, 0.79, 0.97, 0.91, 0.87, 1.0, 0.93, 0.96, 0.81, 0.84, 0.92, 1.0, 1.0, 0.98, 0.83, 0.96, 0.91, 0.92, 0.91, 0.83, 0.
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import os

os.chdir("H:\Water Resources Docs KW\Data Requests")

fig = plt.figure(figsize = (12, 20))
ax = plt.axes(projection ="3d")

#fig.figure(figsize=(30,11))
plt.title(label = 'Correlation between starting storage, daily % change and rainfall total', fontsize= 14,color = 'Black')
plt.xlabel('Date', fontsize=13,color = 'Purple')
plt.ylabel('Volume', fontsize=13, color = 'Blue')


#fig(figsize = (30,11))

x = a_list
y = b_list
z = c_list



ax.scatter(x, y, z, c='b', marker='o',s=20*10)

ax.set_xlabel('Starting_Storage')
ax.set_ylabel('Daily % Change')
ax.set_zlabel('Rainfall (mm)',fontsize = 13, color = 'Red')


plt.savefig('line_plot.pdf')
plt.savefig('line_plot.png')
plt.savefig('line_plot.jpg', dpi=300) 
plt.show()

# %%
# Import libraries
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
 
# Creating dataset
x = a_list
y = b_list
z = c_list
 
# Creating figure
fig = plt.figure(figsize = (16, 9))
ax = plt.axes(projection ="3d")
   
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.3,
        alpha = 0.2)
 
 
# Creating color map
#my_cmap = plt.get_cmap('hsv')
 
# Creating plot
sctt = ax.scatter(x, y, z,
                    alpha = 0.8,
                    c = 'b',
                    s=200,
                    marker ='o')
 
plt.title("simple 3D scatter plot")
ax.set_xlabel('X-axis', fontweight ='bold')
ax.set_ylabel('Y-axis', fontweight ='bold')
ax.set_zlabel('Z-axis', fontweight ='bold')
#fig.colorbar(sctt, ax = ax, shrink = 0.5, aspect = 5)
 
# show plot
plt.show()

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\n460923'

# %%
os.chdir("H:\Water Resources Docs KW\Data Requests")
